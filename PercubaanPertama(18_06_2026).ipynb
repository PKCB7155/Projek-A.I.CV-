# %% [markdown]
# <a href="https://colab.research.google.com/github/PKCB7155/Projek-A.I.CV-/blob/main/PercubaanPertama(18_06_2026).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nama = "Danial"
umur = 19
tahun_lahir = 2026 - umur

print("Nama saya", nama, "dan saya lahir tahun", tahun_lahir)
# Out:
# Nama saya Danial dan saya lahir tahun 2007

# %%
nama_pelajar = input("sila masukkan nama anda: ")
Hobi = input("Apakah hobi anda: ")

print(f"oh, {Hobi} tu sangat menarik, {nama_pelajar}!")
# Out:
# sila masukkan nama anda: Danial
# Apakah hobi anda: Jembut
# oh, Jembut tu sangat menarik, Danial!

# %%
nama1 = "Ramli"
print("saya", nama1, ", saya kawan kepada aiman")
print("awak siapa???")
print("ouh lupa nak kenalkan diri, saya")
name = input("nama anda: ")

Print(f"Nama saya ialah, {nama} dan saya merupakan sepupu Aiman")
# Out:
# saya Ramli , saya kawan kepada aiman
# awak siapa???
# ouh lupa nak kenalkan diri, saya
# nama anda: j
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2871/2366080156.py in <cell line: 0>()
#       5 name = input("nama anda: ")
#       6
# ----> 7 Print(f"Nama saya ialah, {nama} dan saya merupakan sepupu Aiman")
#
# NameError: name 'Print' is not defined

# %%
tahun_lahir = int(input("Tahun lahir anda: "))
umur = 2026 - tahun_lahir

print(f"Umur anda dalam Tahun 2026 ialah {umur} tahun")
# Out:
# Tahun lahir anda: 2007
# Umur anda dalam Tahun 2026 ialah 19 tahun

# %%
mood = input("Perasaan anda harini? (happy/sad): ")

if mood == "happy"
  print("Baguslah")
else mood == "sad"
  Print("Kesian hahahhaah")
# Out:
#   File "/tmp/ipykernel_2871/725506629.py", line 3
#     if mood == "happy"
#                       ^
# SyntaxError: expected ':'

# %%
import random

# Komputer pilih nombor rawak antara 1 hingga 20
nombor_rahsia = random.randint(1, 20)
tekaan = 0

print("Jom main! Saya dah pilih satu nombor antara 1 hingga 20.")

# Gelung akan berjalan selagi tekaan salah
while tekaan != nombor_rahsia:
    tekaan = int(input("Masukkan tekaan anda: "))

    if tekaan < nombor_rahsia:
        print("Terlalu rendah! Cuba lagi.")
    elif tekaan > nombor_rahsia:
        print("Terlalu tinggi! Cuba lagi.")
    else:
        print("Tahniah! Tekaan anda betul! ")
# Out:
# Jom main! Saya dah pilih satu nombor antara 1 hingga 20.
# Masukkan tekaan anda: 7
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 10
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 13
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 17
# Terlalu rendah! Cuba lagi.
# Masukkan tekaan anda: 20
# Tahniah! Tekaan anda betul!

# %% [markdown]
# kalkulator umur kucing

# %%
print("--- KALKULATOR UMUR KUCING ---")

# Ambil input nama dan umur kucing
nama_kucing = input("Masukkan nama kucing anda: ")
umur_manusia = input("Masukkan umur kucing tersebut (dalam tahun manusia): ")

# Tukar input teks (str) kepada nombor (int) untuk dikira
umur_int = int(umur_manusia)

# Formula mudah: 1 tahun manusia bersamaan 7 tahun kucing
umur_kucing = umur_int * 7

print(f"Wah, umur {nama_kucing} dalam tahun kucing adalah {umur_kucing} tahun! ")
# Out:
# --- KALKULATOR UMUR KUCING ---
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2871/327247179.py in <cell line: 0>()
#       2
#       3 # Ambil input nama dan umur kucing
# ----> 4 nama_kucing = input("Masukkan nama kucing anda: ")
#       5 umur_manusia = input("Masukkan umur kucing tersebut (dalam tahun manusia): ")
#       6
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
